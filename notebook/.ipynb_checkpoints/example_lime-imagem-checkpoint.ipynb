# %%
# Auxiliar libs
import sys
import os
import urllib.request
import tarfile
import zipfile
import collections

# Manipulate data
import numpy as np
import pandas as pd


import h5py 
import keras
from keras.applications import inception_v3 as inc_net
from keras.preprocessing import image
from keras.applications.imagenet_utils import decode_predictions

import sklearn
from skimage.segmentation import mark_boundaries

# Explanations
import lime
from lime import lime_image

from anchor import utils
from anchor import anchor_tabular

# Display
from IPython.display import Image
import matplotlib.pyplot as plt

# Jupyter related
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

np.random.seed(1)  # makes the results reproducible
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Explaning a Convolutional Neural Network (Inception) with LIME for Images

# %% [markdown]
# ![](http://i.imgur.com/G3vwhsu.jpg)

# %%
inet_model = inc_net.InceptionV3()

# %%
def transform_img_fn(path_list):
    '''Transform image so it can be processed by inception.'''
    out = []
    for img_path in path_list:
        img = image.load_img(img_path, target_size=(299, 299))
        x = image.img_to_array(img)
        x = np.expand_dims(x, axis=0)
        x = inc_net.preprocess_input(x)
        out.append(x)
    return np.vstack(out)

# %%
import requests

# you can change this URL to any image URL you want!
IMAGE_URL = 'https://raw.githubusercontent.com/marcotcr/lime/master/doc/notebooks/data/cat_mouse.jpg' 
img_data = requests.get(IMAGE_URL).content
with open(os.path.join('data','image.jpg'), 'wb') as handler:
    handler.write(img_data)

# %%
images = transform_img_fn([os.path.join('data','image.jpg')])
# I'm dividing by 2 and adding 0.5 because of how this Inception represents images
# interception representation
plt.imshow(images[0] / 2 + 0.5)
preds = inet_model.predict(images)
for x in decode_predictions(preds)[0]:
    print(x)
# Out:
# ('n02133161', 'American_black_bear', 0.6371611)
# ('n02105056', 'groenendael', 0.031817988)
# ('n02104365', 'schipperke', 0.029944371)
# ('n01883070', 'wombat', 0.028509306)
# ('n01877812', 'wallaby', 0.025093501)

# %%
explainer = lime_image.LimeImageExplainer()

# %%
# %%time
# Hide color is the color for a superpixel turned OFF. Alternatively, if it is NONE, the superpixel will be replaced by the average of its pixels
explanation = explainer.explain_instance(images[0], inet_model.predict, top_labels=5, hide_color=0, num_samples=1000)
# Out:
# CPU times: user 27min 51s, sys: 1min 22s, total: 29min 13s
# Wall time: 5min 23s

# %%
explanation.top_labels
# Out:
# [295, 224, 223, 106, 104]

# %%
temp, mask = explanation.get_image_and_mask(295, positive_only=True, num_features=5, hide_rest=True)
plt.imshow(mark_boundaries(temp / 2 + 0.5, mask))

# %%
temp, mask = explanation.get_image_and_mask(106, positive_only=True, num_features=5, hide_rest=True)
plt.imshow(mark_boundaries(temp / 2 + 0.5, mask))
